# %% [markdown]
# [UMAP](https://umap-learn.readthedocs.io/en/latest/) is a powerful dimensionality reduction tool which NVIDIA recently ported to GPUs with a python interface.  In this notebook we will demostrate basic usage, plotting, and timing comparisons between the CUDA (GPU) version of UMAP and the original CPU version of UMAP

# %%
# !pip install umap-learn
# Out:
# Requirement already satisfied: umap-learn in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (0.5.3)
# Requirement already satisfied: scipy>=1.0 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from umap-learn) (1.9.0)
# Requirement already satisfied: tqdm in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from umap-learn) (4.64.0)
# Requirement already satisfied: numpy>=1.17 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from umap-learn) (1.22.4)
# Requirement already satisfied: scikit-learn>=0.22 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from umap-learn) (1.1.2)
# Requirement already satisfied: pynndescent>=0.5 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from umap-learn) (0.5.7)
# Requirement already satisfied: numba>=0.49 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from umap-learn) (0.55.2)
# Requirement already satisfied: setuptools in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from numba>=0.49->umap-learn) (60.10.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from numba>=0.49->umap-learn) (0.38.1)
# Requirement already satisfied: joblib>=0.11 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from pynndescent>=0.5->umap-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from scikit-learn>=0.22->umap-learn) (3.1.0)

# %%
# !pip install seaborn
# !pip install matplotlib
# Out:
# Requirement already satisfied: seaborn in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: scipy>=1.0 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from seaborn) (1.9.0)
# Requirement already satisfied: numpy>=1.15 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from seaborn) (1.22.4)
# Requirement already satisfied: pandas>=0.23 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from seaborn) (1.4.3)
# Requirement already satisfied: packaging>=20.0 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (4.34.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (9.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: matplotlib in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (3.5.2)
# Requirement already satisfied: cycler>=0.10 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: numpy>=1.17 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from matplotlib) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from matplotlib) (9.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from matplotlib) (4.34.4)
# Requirement already satisfied: six>=1.5 in /home/barradd/miniconda3/envs/rapids-22.06/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# !nvidia-smi
# Out:
# Mon Sep  5 13:38:49 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.141.03   Driver Version: 470.141.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro GV100        Off  | 00000000:AF:00.0  On |                  Off |
# | 35%   50C    P2    34W / 250W |   5202MiB / 32505MiB |     16%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  Quadro GV100        Off  | 00000000:D8:00.0 Off |                  Off |
# | 29%   41C    P2    25W / 250W |    716MiB / 32508MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      2972      G   /usr/lib/xorg/Xorg                104MiB |
# |    0   N/A  N/A      3110      G   /usr/bin/gnome-shell               61MiB |
# |    0   N/A  N/A     15412      G   /usr/lib/xorg/Xorg                440MiB |
# |    0   N/A  N/A     15667      G   /usr/bin/gnome-shell              101MiB |
# |    0   N/A  N/A     16209      G   ...AAAAAAAA== --shared-files       83MiB |
# |    0   N/A  N/A     25031      C   ...s/rapids-22.06/bin/python      713MiB |
# |    0   N/A  N/A     31469      C   ...s/rapids-22.06/bin/python      731MiB |
# |    0   N/A  N/A     34467      C   ...s/rapids-22.06/bin/python     2457MiB |
# |    0   N/A  N/A     59824      G   ...RendererForSitePerProcess      410MiB |
# |    0   N/A  N/A     61899      G   ...156449347264435903,131072       88MiB |
# |    1   N/A  N/A     31466      C   ...s/rapids-22.06/bin/python      713MiB |
# +-----------------------------------------------------------------------------+

# %%
import os
import pandas as pd
import numpy as np

# CPU UMAP
import umap

# libraries for scoring/clustering
from sklearn.manifold import trustworthiness

# GPU UMAP
import cudf
from cuml.manifold.umap import UMAP as cumlUMAP

# plotting
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(style='white', rc={'figure.figsize':(25, 12.5)})

# %% [markdown]
# We are going to work with the [fashion mnist](https://github.com/zalandoresearch/fashion-mnist) data set.  This is a dataset consisting of 70,000 28x28 grayscale images of clothing.

# %%
if not os.path.exists('fashion_mnist'):
    # !git clone https://github.com/zalandoresearch/fashion-mnist.git fashion_mnist
# Out:
# Cloning into 'fashion_mnist'...
# remote: Enumerating objects: 762, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 762 (delta 0), reused 3 (delta 0), pack-reused 758
# Receiving objects: 100% (762/762), 105.85 MiB | 18.46 MiB/s, done.
# Resolving deltas: 100% (444/444), done.

# %%
# https://github.com/zalandoresearch/fashion-mnist/blob/master/utils/mnist_reader.py
def load_mnist(path, kind='train'):
    import os
    import gzip
    import numpy as np

    """Load MNIST data from `path`"""
    labels_path = os.path.join(path,
                               '%s-labels-idx1-ubyte.gz'
                               % kind)
    images_path = os.path.join(path,
                               '%s-images-idx3-ubyte.gz'
                               % kind)

    with gzip.open(labels_path, 'rb') as lbpath:
        labels = np.frombuffer(lbpath.read(), dtype=np.uint8,
                               offset=8)

    with gzip.open(images_path, 'rb') as imgpath:
        images = np.frombuffer(imgpath.read(), dtype=np.uint8,
                               offset=16).reshape(len(labels), 784)

    return images, labels

# %%
train, train_labels = load_mnist('fashion_mnist/data/fashion', kind='train')
test, test_labels = load_mnist('fashion_mnist/data/fashion', kind='t10k')
data = np.array(np.vstack([train, test]), dtype=np.float64) / 255.0
target = np.array(np.hstack([train_labels, test_labels]))

# %% [markdown]
# There are 60000 training images and 10000 test images

# %%
f"Train shape: {train.shape} and Test Shape: {test.shape}"
# Out:
# 'Train shape: (60000, 784) and Test Shape: (10000, 784)'

# %%
train[0].shape
# Out:
# (784,)

# %% [markdown]
# As mentioned previously, each row in the train matrix is an image

# %%
# display a Nike? sneaker
pixels = train[0].reshape((28, 28))
plt.imshow(pixels, cmap='gray')

# %% [markdown]
# There is cost with moving data between host memory and device memory (GPU memory) and we will include that core when comparing speeds

# %%
# %%time
gdf = cudf.DataFrame()
for i in range(data.shape[1]):
    gdf['fea%d'%i] = data[:,i]
# Out:
# CPU times: user 2.33 s, sys: 804 ms, total: 3.14 s
# Wall time: 3.17 s

# %%
# %%timeit
g_embedding = cumlUMAP(n_neighbors=5, init="spectral").fit_transform(gdf)
# Out:
# 2.35 s ± 21 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# `gdf` is a GPU backed dataframe -- all the data is stored in the device memory of the GPU.  With the data converted, we can apply the `cumlUMAP` the same inputs as we do for the standard UMAP.  Additionally, it should be noted that within cuml, [FAISS] https://github.com/facebookresearch/faiss) is used for extremely fast kNN and it's limited to single precision.  `cumlUMAP` will automatically downcast to `float32` when needed.

# %%
# %%timeit
embedding = umap.UMAP(n_neighbors=5, init="spectral").fit_transform(data)
# Out:
# 28.7 s ± 515 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# Compute Runtimes of UMAP training (lower is better):
# - cumlUMAP (GPU): 10.5
# - UMAP (CPU): 100 seconds
#
# cumlMAP is ~9.5x speed up over UMAP CPU.  We should also qualitatively compare output accuracy.  We can do this easily by plotting the embeddings and noting simlarites in the plot

# %%
classes = [
    'T-shirt/top',
    'Trouser',
    'Pullover',
    'Dress',
    'Coat',
    'Sandal',
    'Shirt',
    'Sneaker',
    'Bag',
    'Ankle boot']

# %%
#Needs to be redone because of timeit loses our variables sometimes
embedding = umap.UMAP(n_neighbors=5, init="spectral").fit_transform(data)
g_embedding = cumlUMAP(n_neighbors=5, init="spectral").fit_transform(gdf)

# %% [markdown]
# Just as the original author of UMAP, Leland McInnes, states in the [UMAP docs](https://umap-learn.readthedocs.io/en/latest/supervised.html), we can plot the results and show the separation between the various classes defined above.

# %%
g_embedding_numpy = g_embedding.to_pandas().values #it is necessary to convert to numpy array to do the visual mapping

fig, ax = plt.subplots(1, figsize=(14, 10))
plt.scatter(g_embedding_numpy[:,1], g_embedding_numpy[:,0], s=0.3, c=target, cmap='Spectral', alpha=1.0)
plt.setp(ax, xticks=[], yticks=[])
cbar = plt.colorbar(boundaries=np.arange(11)-0.5)
cbar.set_ticks(np.arange(10))
cbar.set_ticklabels(classes)
plt.title('Fashion MNIST Embedded via cumlUMAP');

# %% [markdown]
# And side-by-side we can see that the separation is very similar between both GPU and CPU versions of UMAP.  Both cluster Ankle Boot, Sneaker, and Sandal together (Green/Yellow/Purple), both separate Trousers and Bags entirely, and both have T-shirts, Shirts, Coats, etc. all mixed toether.

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
ax[0].scatter(g_embedding_numpy[:,1], g_embedding_numpy[:,0], s=0.3, c=target, cmap='Spectral', alpha=1.0)
im = ax[1].scatter(embedding[:,1], embedding[:,0], s=0.3, c=target, cmap='Spectral', alpha=1.0)
ax[0].set_title('Fashion MNIST Embedded via cumlUMAP');
ax[1].set_title('Fashion MNIST Embedded via UMAP');

fig.subplots_adjust(right=0.8)
cax,kw = mpl.colorbar.make_axes([a for a in ax.flat])
cbar = plt.colorbar(im, cax=cax, **kw)
cbar.set_ticks(np.arange(10))
cbar.set_ticklabels(classes)

# %% [markdown]
# Additionally, we can also quanititaviely compare the perfomance of `cumlUMAP` (GPU UMAP) to the reference/original implementation (CPU UMAP) using the [trustworthiness score](https://github.com/scikit-learn/scikit-learn/blob/master/sklearn/manifold/t_sne.py#L395).  From the docstring:
#
# > Trustworthiness expresses to what extent the local structure is retained.  The trustworthiness is within [0, 1].
#
#
# Like `t-SNE`, UMAP tries to capture both global and local structure and thus, we can apply the `trustworthiness` of the `embedding/g_embedding` data against the original input.  With a higher score we are demonstrating that the algorithm does a better and better job of local structure retention.  As [Corey Nolet](https://github.com/cjnolet) notes:
# > Algorithms like UMAP aim to preserve local neighborhood structure and so measuring this property (trustworthiness) measures the algorithm's performance.

# %% [markdown]
# Scoring ~97% shows the GPU implementation is comparable to the original CPU implementation and the training time was ~9.5X faster
